# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
from pdb import set_trace
# %matplotlib notebook

# matplotlib.use('tkagg')
list1 = []
list9 = []
list13 = []
list17 = []
list21 = []
list_valid = []

with open('pred_pass_valid_6415_5415_1x1.csv', 'r') as f:
    lines = f.readlines()
    for line in lines:
        items = line.strip().split(',')
        # items = list(map(float, items[:]))
        list1.append(items)

with open('pred_pass_valid_6415_5415_9x9.csv', 'r') as f:
    lines = f.readlines()
    for line in lines:
        items = line.strip().split(',')
        # items = list(map(float, items[3:]))
        list9.append(items)
        
with open('pred_pass_valid_6415_5415_13x13.csv', 'r') as f:
    lines = f.readlines()
    for line in lines:
        items = line.strip().split(',')
        # items = list(map(float, items[:]))
        list13.append(items)

with open('pred_pass_valid_6415_5415_17x17.csv', 'r') as f:
    lines = f.readlines()
    for line in lines:
        items = line.strip().split(',')
        # items = list(map(float, items[:]))
        list17.append(items)

with open('pred_pass_valid_6415_5415_21x21.csv', 'r') as f:
    lines = f.readlines()
    for line in lines:
        items = line.strip().split(',')
        # items = list(map(float, items[:]))
        list21.append(items)

list1 = np.asarray(list1)
list9 = np.asarray(list9)
list13 = np.asarray(list13)
list21 = np.asarray(list21)

counter = 0
threshold = 0.2
for index in range(len(list9)):
#     all_rows = [list1[index], list9[index], list13[index], list21[index]]
#     all_conf = [float(row[3]) for row in all_rows]
#     all_conf_bool = list(map(lambda a: a>threshold, all_conf))
#     if all(all_conf_bool):
        # idx = all_conf.index(max(all_conf))
        # list_valid.append(all_rows[idx])
    list_valid.append(list1[index])
    counter += 1

    # set_trace()

list_valid = np.asarray(list_valid)

print('number of valid prediction is {}'.format(counter))
print('mean distance of valid prediction is {}'.format(\
                list_valid[:,4].astype(float).mean()))

if len(list_valid) == 0:
    print('empty')

conf = list_valid[:, 3].astype(float)
dist = list_valid[:, 4].astype(float)
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.scatter(conf, dist, color='r')
ax.set_xlabel('confidence')
ax.set_ylabel('euclidean_distance')
fig.suptitle("1x1")
plt.show()

# with open('valid.csv', 'w') as f:
#     for line in list_valid:
#         f.write(','.join(line[:3]) + '\n')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-67a75f2e41cf> in <module>()
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#       4 import matplotlib
#       5 from pdb import set_trace
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
counter = 0
threshold = 0.2
list_valid = []
for index in range(len(list9)):
    list_valid.append(list9[index])
    counter += 1

list_valid = np.asarray(list_valid)

print('number of valid prediction is {}'.format(counter))
print('mean distance of valid prediction is {}'.format(\
                list_valid[:,4].astype(float).mean()))

if len(list_valid) == 0:
    print('empty')

conf = list_valid[:, 3].astype(float)
dist = list_valid[:, 4].astype(float)
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.scatter(conf, dist, color='r')
fig.suptitle("9x9")
ax.set_xlabel('confidence')
ax.set_ylabel('euclidean_distance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-45fb0b86e754> in <module>()
#       2 threshold = 0.2
#       3 list_valid = []
# ----> 4 for index in range(len(list9)):
#       5     list_valid.append(list9[index])
#       6     counter += 1
#
# NameError: name 'list9' is not defined

# %%
counter = 0
threshold = 0.2
list_valid = []
for index in range(len(list9)):
    list_valid.append(list13[index])
    counter += 1

list_valid = np.asarray(list_valid)

print('number of valid prediction is {}'.format(counter))
print('mean distance of valid prediction is {}'.format(\
                list_valid[:,4].astype(float).mean()))

if len(list_valid) == 0:
    print('empty')

conf = list_valid[:, 3].astype(float)
dist = list_valid[:, 4].astype(float)
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.scatter(conf, dist, color='r')
fig.suptitle("13x13")
ax.set_xlabel('confidence')
ax.set_ylabel('euclidean_distance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e5678cfeff31> in <module>()
#       2 threshold = 0.2
#       3 list_valid = []
# ----> 4 for index in range(len(list9)):
#       5     list_valid.append(list13[index])
#       6     counter += 1
#
# NameError: name 'list9' is not defined

# %%
counter = 0
threshold = 0.2
list_valid = []
for index in range(len(list9)):
    list_valid.append(list17[index])
    counter += 1

list_valid = np.asarray(list_valid)

print('number of valid prediction is {}'.format(counter))
print('mean distance of valid prediction is {}'.format(\
                list_valid[:,4].astype(float).mean()))

if len(list_valid) == 0:
    print('empty')

conf = list_valid[:, 3].astype(float)
dist = list_valid[:, 4].astype(float)
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.scatter(conf, dist, color='r')
fig.suptitle("17x17")
ax.set_xlabel('confidence')
ax.set_ylabel('euclidean_distance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-52f51c6048be> in <module>()
#       2 threshold = 0.2
#       3 list_valid = []
# ----> 4 for index in range(len(list9)):
#       5     list_valid.append(list17[index])
#       6     counter += 1
#
# NameError: name 'list9' is not defined

# %%
counter = 0
threshold = 0.2
list_valid = []
for index in range(len(list9)):
    list_valid.append(list21[index])
    counter += 1

list_valid = np.asarray(list_valid)

print('number of valid prediction is {}'.format(counter))
print('mean distance of valid prediction is {}'.format(\
                list_valid[:,4].astype(float).mean()))

if len(list_valid) == 0:
    print('empty')

conf = list_valid[:, 3].astype(float)
dist = list_valid[:, 4].astype(float)
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.scatter(conf, dist, color='r')
fig.suptitle("21x21")
ax.set_xlabel('confidence')
ax.set_ylabel('euclidean_distance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c8cb046e70f7> in <module>()
#       2 threshold = 0.2
#       3 list_valid = []
# ----> 4 for index in range(len(list9)):
#       5     list_valid.append(list21[index])
#       6     counter += 1
#
# NameError: name 'list9' is not defined

# %%
counter = 0
threshold = 0.2
list_valid = []
for index in range(len(list9)):
    all_rows = [\
                list1[index], \
#                 list9[index], \
                list13[index], \
                list17[index], \
                list21[index],\
               ]
    all_conf = [float(row[3]) for row in all_rows]
    all_conf_bool = list(map(lambda a: a>threshold, all_conf))
    if all(all_conf_bool):
        # idx = all_conf.index(max(all_conf))
        # list_valid.append(all_rows[idx])
        list_valid.append(list13[index])
        counter += 1

    # set_trace()

list_valid = np.asarray(list_valid)

print('number of valid prediction is {}'.format(counter))
print('mean distance of valid prediction is {}'.format(\
                list_valid[:,4].astype(float).mean()))

if len(list_valid) == 0:
    print('empty')

conf = list_valid[:, 3].astype(float)
dist = list_valid[:, 4].astype(float)
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.9,0.9])
ax.scatter(conf, dist, color='r')
ax.set_xlabel('confidence')
ax.set_ylabel('euclidean_distance')
fig.suptitle("combined all")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4ba2085078a8> in <module>()
#       2 threshold = 0.2
#       3 list_valid = []
# ----> 4 for index in range(len(list9)):
#       5     all_rows = [                list1[index], #                 list9[index], \
#       6                 list13[index], \
#
# NameError: name 'list9' is not defined
