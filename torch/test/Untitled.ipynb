# %%
import torch
import matplotlib.pyplot as plt
from PIL import Image
from torchvision.transforms import Compose, ToTensor, functional as K
import numpy as np
import os

# %matplotlib inline

# %%
image_name = "IMG010218072553.jpg"
image_name = os.path.join("../all_images/", image_name)
image_pil = Image.open(image_name, 'r')
plt.imshow(np.asarray(image_pil))

# %%
# transform = Compose([ToTensor(), K.crop()])
image_pil = K.crop(image_pil, 630-20,600-20,40,40)
# image_tensor = ToTensor()(image_pil)
plt.imshow(np.asarray(image_pil))

# %%
print(np.asarray(image_pil).max())
print(np.asarray(image_pil).min())
# Out:
# 255
# 3

# %%
print(np.asarray(image_pil).shape)
# Out:
# (300, 300)
